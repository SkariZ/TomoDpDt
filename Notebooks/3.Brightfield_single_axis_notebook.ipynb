# %% [markdown]
# # Brightfield Reconstruction with Single-Axis Rotation
#
# This notebook extends the [**Base Brightfield Notebook (Gaussian Blobs)**](./1.Brightfield_base_notebook.ipynb)
# by exploring a **simplified rotational case** — a 3D object rotating smoothly around a **single, fixed axis**.
#
# While the base and potato notebooks demonstrated reconstruction under oscillatory, randomly varying rotation,
# this experiment isolates a **controlled single-axis motion**.
# This makes it easier to study reconstruction stability, evaluate quaternion accuracy,
# and understand how the optimization behaves when motion is physically constrained.
#
# We reuse the same **Brightfield imaging model**, **VAE-based initialization**, and **gradient-based optimization** workflow.
# Only the **rotation pattern** differs — making this notebook a compact validation study of the method’s accuracy under simpler motion.
#
# If you need theoretical explanations (tomography principles, loss terms, or VAE setup),
# please refer to the [base notebook](./1.Brightfield_base_notebook.ipynb).
#
# ---
#
# ### **Notebook Outline**
#
# 1. **Load the Test Volume**
#    Import the `test_data/potato.npy` (or another object) and visualize central slices.
#
# 2. **Set Up Brightfield Imaging Model**
#    Configure the optics and imaging model identical to the base notebook.
#
# 3. **Generate Projections – Single-Axis Rotation**
#    Simulate 2D projections while rotating the object around one fixed axis (e.g., `z`).
#
# 4. **Reconstruct the 3D Volume**
#    Run the Tomography model to refine the volume and rotation parameters.
#
# 5. **Evaluate and Visualize**
#    Compare the reconstructed volume to the ground truth and inspect quaternion trajectories,
#    which should now align predominantly along a single axis.
#
# 6. **Save and Compare**
#    Export the reconstructed data for direct comparison with results from oscillatory-rotation cases.
#
# > **Note:** This notebook focuses on controlled single-axis rotation to validate the reconstruction accuracy and rotation recovery under simplified motion conditions.

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/SkariZ/TomoDpDt/blob/main/Notebooks/sum_projection_vobble.ipynb)

# %%
# Uncomment if you run this notebook in Google Colab
#!pip install deeplay deeptrack plotly scipy opencv-python
#!git clone https://github.com/SkariZ/TomoDpDt.git
#import sys
#sys.path.append('/content/TomoDpDt')

# %%
# Uncomment if running this notebook locally
#import sys
#sys.path.append('..')

# %%
import sys
sys.path.append('..')

import tomodpdt

import numpy as np
import time

import deeplay as dl
import torch
from torch.utils.data import DataLoader

# %%
DEV = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Using device:', DEV)
# Out:
# Using device: cuda

# %% [markdown]
# ## 1. Load 3D Volume
#
# In this example, we load a **3D volume of a potato-like object**, which serves as a simple synthetic test sample.
# The volume mimics a structure with **localized regions of higher refractive index**, similar to how real biological or soft-matter samples may contain internal inhomogeneities.
#
# This object is precomputed and stored in the `test_data/` folder, allowing for direct use without additional generation steps.

# %%
volume = np.load('../test_data/vol_potato1.npy')

# %%
print(f"Shape of the volume: {volume.shape}")
# Out:
# Shape of the volume: (64, 64, 64)

# %% [markdown]
# The volume has refractive index values in the range 1.33-1.42.

# %%
volume.max(), volume.min(), volume.mean(), volume.std()
# Out:
# (1.4200001, 1.33, 1.3315866, 0.0052548475)

# %% [markdown]
# For optimization purposes it easier to work with the refractive index difference, assuming the sample is in water we can subtract 1.33.

# %%
volume = volume - 1.33

# %% [markdown]
# The 3D volume is stored in a `numpy` array and can be interactively visualized using the `ipyvolume` library together with `plotly`. Having it interactive and saving the `.ipynb` however make the file extremely large. Uncomment the code below for interactive plot.

# %%
# tomodpdt.plotting.visualize_3d_volume(volume)

# %% [markdown]
# Using sum projections along the x, y, and z axes, we can visualize the structure of the volume.

# %%
tomodpdt.plotting.plot_sum_object(volume)

# %% [markdown]
# ## 2. Set Up Brightfield Imaging Model

# %%
from tomodpdt.imaging_modality_torch import setup_optics, imaging_model

# --- Setup the optical system ---
optics_settings = setup_optics(
    shape=volume.shape,       # Shape of the 3D volume
    padding_xy=volume.shape[0]//2,  # Padding in the lateral directions (avoids wrap-around effects)
    microscopy_regime='Brightfield', # Choose microscopy type: 'Brightfield', 'Fluorescence', etc.
    NA=1.1,                      # Numerical Aperture of the objective
    wavelength=520e-9,           # Illumination wavelength in meters
    resolution=200e-9,           # Effective pixel resolution in meters
    magnification=1,             # System magnification
    return_field=True            # Return the complex optical field instead of intensity only
)

# --- Build the imaging model ---
brightfield_model = imaging_model(optics_setup=optics_settings)

# %% [markdown]
# ## 3. Generate Projections - Single-Axis Rotation
#
# In this example, the 3D object is rotated around a **single, fixed axis**. This setup represents a more controlled and physically simple rotation compared to the oscillatory or random-axis cases in previous notebooks.

# %%
test_object, q_gt, projections, imaging_model = tomodpdt.simulate.create_data(
    volume=volume, # The volume we want to reconstruct
    image_modality=brightfield_model, # We use the sum model
    rotation_case='1ax', # One-axis rotation. Can be either "y" or "x" axis.
    samples=200, # Number of projections
    duration=2 # Duration is the number of full revolutions
    )
# Out:
# Simulating... 50.0%

# %% [markdown]
# ### 3.2 Visualizing the Training Data
#
# In this section, we explore the generated training data through the forward images and the corresponding rotation parameters.

# %% [markdown]
# #### Vizualising the forward projections

# %%
tomodpdt.plotting.plot_grid33_frames(projections, title="Projections", randomize=True)

# %% [markdown]
# #### Visualizing the Quaternion Trajectory

# %%
tomodpdt.plotting.plot_quaternions(q_gt)

# %% [markdown]
# ## 4. Reconstruct the 3D Volume
#
# In this section, we focus on **tomographic reconstruction**, that is, the process of recovering a 3D volume from a set of 2D projection images acquired under different viewing angles.

# %% [markdown]
# #### Create the tomographic model

# %%
tomographic_model = tomodpdt.Tomography(
    volume_size=volume.shape, # The size of the volume
    initial_volume='zeros', # 'refraction' since we are optimizing the refractive index
    rotation_optim_case='basis', # 'basis' or 'quaternion', 'basis' is smoother
    imaging_model=brightfield_model, # The imaging model
    )

# %% [markdown]
# #### Initialize the parameters

# %%
tomographic_model.initialize_parameters(projections, normalize=False, max_epochs=100)
# Out:
# c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\trainer\connectors\logger_connector\logger_connector.py:76: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `lightning.pytorch` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
# c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name                | Type                 | Params | Mode
# ---------------------------------------------------------------------
# 0 | encoder             | Sequential           | 79.8 K | train
# 1 | fc_mu               | MultiLayerPerceptron | 32.8 K | train
# 2 | fc_var              | MultiLayerPerceptron | 32.8 K | train
# 3 | fc_dec              | MultiLayerPerceptron | 51.3 K | train
# 4 | decoder             | Sequential           | 61.3 K | train
# 5 | reconstruction_loss | L1Loss               | 0      | train
# 6 | train_metrics       | MetricCollection     | 0      | train
# 7 | val_metrics         | MetricCollection     | 0      | train
# 8 | test_metrics        | MetricCollection     | 0      | train
# 9 | optimizer           | Adam                 | 0      | train
# ---------------------------------------------------------------------
# 258 K     Trainable params
# 0         Non-trainable params
# 258 K     Total params
# 1.032     Total estimated model params size (MB)
# 77        Modules in train mode
# 0         Modules in eval mode
# c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\loops\fit_loop.py:310: The number of training batches (7) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Epoch 99: 100%|██████████| 7/7 [00:00<00:00, 70.48it/s, v_num=1627, train_rec_loss_step=0.0636, train_KL_step=5.380, train_total_loss_step=0.0637, train_rec_loss_epoch=0.0634, train_KL_epoch=12.80, train_total_loss_epoch=0.0636]
# c:\Users\Fredrik\Documents\GitHub\TomoDpDt\Notebooks\..\tomodpdt\estimate_rotations_from_latent.py:219: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:281.)
#   frames = torch.tensor(frames, dtype=torch.float32)
# ✅ Found 3 peaks after 3 tries (prom=0.0250, width=6.40)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Fredrik\Documents\GitHub\TomoDpDt\Notebooks\..\tomodpdt\application.py:360, in Tomography.initialize_parameters(self, projections, **kwargs)
#     359 try:
# --> 360     self.rotation_initial_dict = erfl.process_latent_space(
#     361         z=latent_space,
#     362         frames=projections,  # optical flow / latent smoothness uses padded data
#     363         **kwargs
#     364     )
#     365     print("Rotation initialization from latent space successful.")
#
# File c:\Users\Fredrik\Documents\GitHub\TomoDpDt\Notebooks\..\tomodpdt\estimate_rotations_from_latent.py:144, in process_latent_space(z, frames, initial_axes, quaternions, initial_frames_per_rotation, peaks_period_range, window_length, polyorder, max_peaks, min_peaks, prominence, width, basis_functions, initial_axes_case, rotation_period, **kwargs)
#     143 if len(peaks) < min_peaks:
# --> 144     raise ValueError("Not enough peaks detected for angle estimation.")
#     146 # Interpolate angles between peaks
#
# ValueError: Not enough peaks detected for angle estimation.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 tomographic_model.initialize_parameters(projections, normalize=False, max_epochs=100)
#
# File c:\Users\Fredrik\Documents\GitHub\TomoDpDt\Notebooks\..\tomodpdt\application.py:367, in Tomography.initialize_parameters(self, projections, **kwargs)
#     365     print("Rotation initialization from latent space successful.")
#     366 except:
# --> 367     self.rotation_initial_dict = erfl.process_cross_correlation(
#     368         frames=projections,
#     369         **kwargs
#     370     )
#     371     print("Rotation initialization from latent space failed, using cross-correlation instead.")
#     374 # -------------------------------------------------------
#     375 # --- 5. Set rotation parameters
#     376 # -------------------------------------------------------
#
# File c:\Users\Fredrik\Documents\GitHub\TomoDpDt\Notebooks\..\tomodpdt\estimate_rotations_from_latent.py:239, in process_cross_correlation(frames, normalize, width, prominence, rotation_period, initial_axes, initial_axes_case, basis_functions, **kwargs)
#     237 if initial_axes is None:
#     238     if initial_axes_case == 'cv2_flow':
# --> 239         flow_vectors = compute_optical_flow(frames[:, 0].cpu().numpy())
#     240         initial_axes = classify_rotation_axis(flow_vectors)
#     241     elif initial_axes_case == 'std':
#
# File c:\Users\Fredrik\Documents\GitHub\TomoDpDt\Notebooks\..\tomodpdt\estimate_rotations_from_latent.py:387, in compute_optical_flow(frames)
#     381 def compute_optical_flow(frames):
#     382     """
#     383     Computes dense optical flow between consecutive frames.
#     384     :param frames: NumPy array of shape (T, 64, 64) with values in range [0,1].
#     385     :return: Motion vectors (dx, dy) for sampled points.
#     386     """
# --> 387     T, H, W = frames.shape
#     388     flow_vectors = []
#     390     for t in range(T - 1):
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %% [markdown]
# For vizualisation we initialize a `TomoPlotter` class for easier plotting.

# %%
plotter = tomodpdt.plotting.TomoPlotter(tomographic_model)

# %% [markdown]
# #### Visualizing the Latent Space Trajectory, Peaks and the Initial Guess

# %%
plotter.plot_latent_space()

# %%
plotter.plot_smooth_dist_intial_guess(q_gt=q_gt)

# %%
plotter.plot_reconstructed_vs_gt()

# %% [markdown]
# ### 4.1 Start the 3D Reconstruction Optimization

# %%
N1 = len(tomographic_model.frames) # Number of frames
idx = torch.arange(N1) # List of indexes
epochs_object_only = 50 # Number of epochs for the object only optimization
batch_size_object_only = 32 # Batch size for the object only optimization

# %%
# Toggle the gradients of the quaternion parameters to False
tomographic_model.toggle_gradients_quaternion(False)

# Toggle the gradients of the translation parameters to False
tomographic_model.toggle_gradients_translation(False)

# Move the model to device and all parameters
tomographic_model.move_all_to_device(DEV)

# %%
# Train the model
start_time = time.time()
trainer = dl.Trainer(max_epochs=epochs_object_only, accelerator="auto", log_every_n_steps=10)
trainer.fit(tomographic_model, DataLoader(idx, batch_size=batch_size_object_only , shuffle=True))
print("Training time: ", (time.time() - start_time) / 60, " minutes")

# Plot the training history
try:
    trainer.history.plot()
except:
    print("No history to plot...")
# Out:
#   | Name          | Type                   | Params | Mode
# -----------------------------------------------------------------
# 0 | vae_model     | VariationalAutoEncoder | 258 K  | train
# 1 | encoder       | Sequential             | 79.8 K | train
# 2 | fc_mu         | MultiLayerPerceptron   | 32.8 K | train
# 3 | imaging_model | imaging_model          | 0      | train
# 4 | train_metrics | MetricCollection       | 0      | train
# 5 | val_metrics   | MetricCollection       | 0      | train
# 6 | test_metrics  | MetricCollection       | 0      | train
# 7 | optimizer     | Adam                   | 0      | train
#   | other params  | n/a                    | 150 K  | n/a
# -----------------------------------------------------------------
# 262 K     Trainable params
# 258 K     Non-trainable params
# 520 K     Total params
# 2.083     Total estimated model params size (MB)
# 83        Modules in train mode
# 0         Modules in eval mode
# c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\loops\fit_loop.py:310: The number of training batches (7) is smaller than the logging interval Trainer(log_every_n_steps=10). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Epoch 3:   0%|          | 0/7 [00:00<?, ?it/s, v_num=1626, train_total_loss_step=0.138, train_proj_loss_step=0.0701, train_latent_loss_step=0.0357, train_rtv_loss_step=0.00579, train_so_loss_step=0.0269, train_total_loss_epoch=0.193, train_proj_loss_epoch=0.090, train_latent_loss_epoch=0.0699, train_rtv_loss_epoch=0.00559, train_so_loss_epoch=0.0274]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\trainer\call.py:48, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      47         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 48     return trainer_fn(*args, **kwargs)
#      50 except _TunerExitException:
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\trainer\trainer.py:599, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     593 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     594     self.state.fn,
#     595     ckpt_path,
#     596     model_provided=True,
#     597     model_connected=self.lightning_module is not None,
#     598 )
# --> 599 self._run(model, ckpt_path=ckpt_path)
#     601 assert self.state.stopped
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\trainer\trainer.py:1012, in Trainer._run(self, model, ckpt_path)
#    1009 # ----------------------------
#    1010 # RUN THE TRAINER
#    1011 # ----------------------------
# -> 1012 results = self._run_stage()
#    1014 # ----------------------------
#    1015 # POST-Training CLEAN UP
#    1016 # ----------------------------
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\trainer\trainer.py:1056, in Trainer._run_stage(self)
#    1055 with torch.autograd.set_detect_anomaly(self._detect_anomaly):
# -> 1056     self.fit_loop.run()
#    1057 return None
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\loops\fit_loop.py:216, in _FitLoop.run(self)
#     215 self.on_advance_start()
# --> 216 self.advance()
#     217 self.on_advance_end()
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\loops\fit_loop.py:455, in _FitLoop.advance(self)
#     454 assert self._data_fetcher is not None
# --> 455 self.epoch_loop.run(self._data_fetcher)
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\loops\training_epoch_loop.py:150, in _TrainingEpochLoop.run(self, data_fetcher)
#     149 try:
# --> 150     self.advance(data_fetcher)
#     151     self.on_advance_end(data_fetcher)
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\loops\training_epoch_loop.py:320, in _TrainingEpochLoop.advance(self, data_fetcher)
#     318 if trainer.lightning_module.automatic_optimization:
#     319     # in automatic optimization, there can only be one optimizer
# --> 320     batch_output = self.automatic_optimization.run(trainer.optimizers[0], batch_idx, kwargs)
#     321 else:
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\loops\optimization\automatic.py:192, in _AutomaticOptimization.run(self, optimizer, batch_idx, kwargs)
#     187 # ------------------------------
#     188 # BACKWARD PASS
#     189 # ------------------------------
#     190 # gradient update with accumulated gradients
#     191 else:
# --> 192     self._optimizer_step(batch_idx, closure)
#     194 result = closure.consume_result()
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\loops\optimization\automatic.py:270, in _AutomaticOptimization._optimizer_step(self, batch_idx, train_step_and_backward_closure)
#     269 # model hook
# --> 270 call._call_lightning_module_hook(
#     271     trainer,
#     272     "optimizer_step",
#     273     trainer.current_epoch,
#     274     batch_idx,
#     275     optimizer,
#     276     train_step_and_backward_closure,
#     277 )
#     279 if not should_accumulate:
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\trainer\call.py:176, in _call_lightning_module_hook(trainer, hook_name, pl_module, *args, **kwargs)
#     175 with trainer.profiler.profile(f"[LightningModule]{pl_module.__class__.__name__}.{hook_name}"):
# --> 176     output = fn(*args, **kwargs)
#     178 # restore current_fx when nested context
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\core\module.py:1302, in LightningModule.optimizer_step(self, epoch, batch_idx, optimizer, optimizer_closure)
#    1278 r"""Override this method to adjust the default way the :class:`~lightning.pytorch.trainer.trainer.Trainer` calls
#    1279 the optimizer.
#    1280
#    (...)   1300
#    1301 """
# -> 1302 optimizer.step(closure=optimizer_closure)
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\core\optimizer.py:154, in LightningOptimizer.step(self, closure, **kwargs)
#     153 assert self._strategy is not None
# --> 154 step_output = self._strategy.optimizer_step(self._optimizer, closure, **kwargs)
#     156 self._on_after_step()
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\strategies\strategy.py:239, in Strategy.optimizer_step(self, optimizer, closure, model, **kwargs)
#     238 assert isinstance(model, pl.LightningModule)
# --> 239 return self.precision_plugin.optimizer_step(optimizer, model=model, closure=closure, **kwargs)
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\plugins\precision\precision.py:123, in Precision.optimizer_step(self, optimizer, model, closure, **kwargs)
#     122 closure = partial(self._wrap_closure, model, optimizer, closure)
# --> 123 return optimizer.step(closure=closure, **kwargs)
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\torch\optim\optimizer.py:487, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     483             raise RuntimeError(
#     484                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     485             )
# --> 487 out = func(*args, **kwargs)
#     488 self._optimizer_step_code()
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\torch\optim\optimizer.py:91, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      90     torch._dynamo.graph_break()
# ---> 91     ret = func(self, *args, **kwargs)
#      92 finally:
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\torch\optim\adam.py:202, in Adam.step(self, closure)
#     201     with torch.enable_grad():
# --> 202         loss = closure()
#     204 for group in self.param_groups:
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\plugins\precision\precision.py:109, in Precision._wrap_closure(self, model, optimizer, closure)
#     102 """This double-closure allows makes sure the ``closure`` is executed before the ``on_before_optimizer_step``
#     103 hook is called.
#     104
#    (...)    107
#     108 """
# --> 109 closure_result = closure()
#     110 self._after_closure(model, optimizer)
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\loops\optimization\automatic.py:146, in Closure.__call__(self, *args, **kwargs)
#     144 @override
#     145 def __call__(self, *args: Any, **kwargs: Any) -> Optional[Tensor]:
# --> 146     self._result = self.closure(*args, **kwargs)
#     147     return self._result.loss
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     115 with ctx_factory():
# --> 116     return func(*args, **kwargs)
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\loops\optimization\automatic.py:140, in Closure.closure(self, *args, **kwargs)
#     139 if self._backward_fn is not None and step_output.closure_loss is not None:
# --> 140     self._backward_fn(step_output.closure_loss)
#     142 return step_output
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\loops\optimization\automatic.py:241, in _AutomaticOptimization._make_backward_fn.<locals>.backward_fn(loss)
#     240 def backward_fn(loss: Tensor) -> None:
# --> 241     call._call_strategy_hook(self.trainer, "backward", loss, optimizer)
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\trainer\call.py:328, in _call_strategy_hook(trainer, hook_name, *args, **kwargs)
#     327 with trainer.profiler.profile(f"[Strategy]{trainer.strategy.__class__.__name__}.{hook_name}"):
# --> 328     output = fn(*args, **kwargs)
#     330 # restore current_fx when nested context
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\strategies\strategy.py:213, in Strategy.backward(self, closure_loss, optimizer, *args, **kwargs)
#     211 closure_loss = self.precision_plugin.pre_backward(closure_loss, self.lightning_module)
# --> 213 self.precision_plugin.backward(closure_loss, self.lightning_module, optimizer, *args, **kwargs)
#     215 closure_loss = self.precision_plugin.post_backward(closure_loss, self.lightning_module)
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\plugins\precision\precision.py:73, in Precision.backward(self, tensor, model, optimizer, *args, **kwargs)
#      62 r"""Performs the actual backpropagation.
#      63
#      64 Args:
#    (...)     71
#      72 """
# ---> 73 model.backward(tensor, *args, **kwargs)
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\core\module.py:1097, in LightningModule.backward(self, loss, *args, **kwargs)
#    1096 else:
# -> 1097     loss.backward(*args, **kwargs)
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\torch\_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)    579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\torch\autograd\graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 4
#       2 start_time = time.time()
#       3 trainer = dl.Trainer(max_epochs=epochs_object_only, accelerator="auto", log_every_n_steps=10)
# ----> 4 trainer.fit(tomographic_model, DataLoader(idx, batch_size=batch_size_object_only , shuffle=True))
#       5 print("Training time: ", (time.time() - start_time) / 60, " minutes")
#       7 # Plot the training history
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\trainer\trainer.py:561, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     559 self.training = True
#     560 self.should_stop = False
# --> 561 call._call_and_handle_interrupt(
#     562     self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     563 )
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\trainer\call.py:65, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      63     if isinstance(launcher, _SubprocessScriptLauncher):
#      64         launcher.kill(_get_sigkill_signal())
# ---> 65     exit(1)
#      67 except BaseException as exception:
#      68     _interrupt(trainer, exception)
#
# NameError: name 'exit' is not defined

# %% [markdown]
# ### 4.2 Optimize the 3D volume and the rotation parameters

# %%
epochs_object_rot = 500 # Number of epochs for the object and rotation optimization
batch_size_object_rot = 32 # Batch size for the object and rotation optimization

# %%
# Toggle the gradients of the quaternion parameters
tomographic_model.toggle_gradients_quaternion(True)

# The gradients of the translation parameters are already False and remain so since we do not want to optimize them now
# tomographic_model.toggle_gradients_translation(False)

# Move the model to device
tomographic_model.move_all_to_device(DEV)

# %% [markdown]
# and train the model for `epochs_object_rot` epochs...

# %%
# Train the model
start_time = time.time()
trainer = dl.Trainer(max_epochs=epochs_object_rot, accelerator="auto", log_every_n_steps=None)
trainer.fit(tomographic_model, DataLoader(idx, batch_size=batch_size_object_rot , shuffle=True))
print("Training time: ", (time.time() - start_time) / 60, " minutes")

# Plot the training history
try:
    trainer.history.plot()
except:
    print("No history to plot...")
# Out:
#   | Name          | Type                   | Params | Mode
# -----------------------------------------------------------------
# 0 | vae_model     | VariationalAutoEncoder | 258 K  | train
# 1 | encoder       | Sequential             | 79.8 K | train
# 2 | fc_mu         | MultiLayerPerceptron   | 32.8 K | train
# 3 | imaging_model | imaging_model          | 0      | train
# 4 | train_metrics | MetricCollection       | 0      | train
# 5 | val_metrics   | MetricCollection       | 0      | train
# 6 | test_metrics  | MetricCollection       | 0      | train
# 7 | optimizer     | Adam                   | 0      | train
#   | other params  | n/a                    | 150 K  | n/a
# -----------------------------------------------------------------
# 262 K     Trainable params
# 258 K     Non-trainable params
# 520 K     Total params
# 2.083     Total estimated model params size (MB)
# 83        Modules in train mode
# 0         Modules in eval mode
# c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\loops\fit_loop.py:310: The number of training batches (7) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Epoch 8:  14%|█▍        | 1/7 [00:00<00:02,  2.57it/s, v_num=1619, train_total_loss_step=0.0401, train_proj_loss_step=0.0187, train_latent_loss_step=0.0168, train_rtv_loss_step=0.00396, train_so_loss_step=0.000584, train_total_loss_epoch=0.0431, train_proj_loss_epoch=0.0189, train_latent_loss_epoch=0.0196, train_rtv_loss_epoch=0.00399, train_so_loss_epoch=0.000583]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\trainer\call.py:48, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      47         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 48     return trainer_fn(*args, **kwargs)
#      50 except _TunerExitException:
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\trainer\trainer.py:599, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     593 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     594     self.state.fn,
#     595     ckpt_path,
#     596     model_provided=True,
#     597     model_connected=self.lightning_module is not None,
#     598 )
# --> 599 self._run(model, ckpt_path=ckpt_path)
#     601 assert self.state.stopped
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\trainer\trainer.py:1012, in Trainer._run(self, model, ckpt_path)
#    1009 # ----------------------------
#    1010 # RUN THE TRAINER
#    1011 # ----------------------------
# -> 1012 results = self._run_stage()
#    1014 # ----------------------------
#    1015 # POST-Training CLEAN UP
#    1016 # ----------------------------
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\trainer\trainer.py:1056, in Trainer._run_stage(self)
#    1055 with torch.autograd.set_detect_anomaly(self._detect_anomaly):
# -> 1056     self.fit_loop.run()
#    1057 return None
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\loops\fit_loop.py:216, in _FitLoop.run(self)
#     215 self.on_advance_start()
# --> 216 self.advance()
#     217 self.on_advance_end()
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\loops\fit_loop.py:455, in _FitLoop.advance(self)
#     454 assert self._data_fetcher is not None
# --> 455 self.epoch_loop.run(self._data_fetcher)
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\loops\training_epoch_loop.py:150, in _TrainingEpochLoop.run(self, data_fetcher)
#     149 try:
# --> 150     self.advance(data_fetcher)
#     151     self.on_advance_end(data_fetcher)
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\loops\training_epoch_loop.py:320, in _TrainingEpochLoop.advance(self, data_fetcher)
#     318 if trainer.lightning_module.automatic_optimization:
#     319     # in automatic optimization, there can only be one optimizer
# --> 320     batch_output = self.automatic_optimization.run(trainer.optimizers[0], batch_idx, kwargs)
#     321 else:
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\loops\optimization\automatic.py:192, in _AutomaticOptimization.run(self, optimizer, batch_idx, kwargs)
#     187 # ------------------------------
#     188 # BACKWARD PASS
#     189 # ------------------------------
#     190 # gradient update with accumulated gradients
#     191 else:
# --> 192     self._optimizer_step(batch_idx, closure)
#     194 result = closure.consume_result()
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\loops\optimization\automatic.py:270, in _AutomaticOptimization._optimizer_step(self, batch_idx, train_step_and_backward_closure)
#     269 # model hook
# --> 270 call._call_lightning_module_hook(
#     271     trainer,
#     272     "optimizer_step",
#     273     trainer.current_epoch,
#     274     batch_idx,
#     275     optimizer,
#     276     train_step_and_backward_closure,
#     277 )
#     279 if not should_accumulate:
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\trainer\call.py:176, in _call_lightning_module_hook(trainer, hook_name, pl_module, *args, **kwargs)
#     175 with trainer.profiler.profile(f"[LightningModule]{pl_module.__class__.__name__}.{hook_name}"):
# --> 176     output = fn(*args, **kwargs)
#     178 # restore current_fx when nested context
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\core\module.py:1302, in LightningModule.optimizer_step(self, epoch, batch_idx, optimizer, optimizer_closure)
#    1278 r"""Override this method to adjust the default way the :class:`~lightning.pytorch.trainer.trainer.Trainer` calls
#    1279 the optimizer.
#    1280
#    (...)   1300
#    1301 """
# -> 1302 optimizer.step(closure=optimizer_closure)
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\core\optimizer.py:154, in LightningOptimizer.step(self, closure, **kwargs)
#     153 assert self._strategy is not None
# --> 154 step_output = self._strategy.optimizer_step(self._optimizer, closure, **kwargs)
#     156 self._on_after_step()
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\strategies\strategy.py:239, in Strategy.optimizer_step(self, optimizer, closure, model, **kwargs)
#     238 assert isinstance(model, pl.LightningModule)
# --> 239 return self.precision_plugin.optimizer_step(optimizer, model=model, closure=closure, **kwargs)
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\plugins\precision\precision.py:123, in Precision.optimizer_step(self, optimizer, model, closure, **kwargs)
#     122 closure = partial(self._wrap_closure, model, optimizer, closure)
# --> 123 return optimizer.step(closure=closure, **kwargs)
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\torch\optim\optimizer.py:487, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     483             raise RuntimeError(
#     484                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     485             )
# --> 487 out = func(*args, **kwargs)
#     488 self._optimizer_step_code()
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\torch\optim\optimizer.py:91, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      90     torch._dynamo.graph_break()
# ---> 91     ret = func(self, *args, **kwargs)
#      92 finally:
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\torch\optim\adam.py:202, in Adam.step(self, closure)
#     201     with torch.enable_grad():
# --> 202         loss = closure()
#     204 for group in self.param_groups:
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\plugins\precision\precision.py:109, in Precision._wrap_closure(self, model, optimizer, closure)
#     102 """This double-closure allows makes sure the ``closure`` is executed before the ``on_before_optimizer_step``
#     103 hook is called.
#     104
#    (...)    107
#     108 """
# --> 109 closure_result = closure()
#     110 self._after_closure(model, optimizer)
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\loops\optimization\automatic.py:146, in Closure.__call__(self, *args, **kwargs)
#     144 @override
#     145 def __call__(self, *args: Any, **kwargs: Any) -> Optional[Tensor]:
# --> 146     self._result = self.closure(*args, **kwargs)
#     147     return self._result.loss
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     115 with ctx_factory():
# --> 116     return func(*args, **kwargs)
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\loops\optimization\automatic.py:131, in Closure.closure(self, *args, **kwargs)
#     128 @override
#     129 @torch.enable_grad()
#     130 def closure(self, *args: Any, **kwargs: Any) -> ClosureResult:
# --> 131     step_output = self._step_fn()
#     133     if step_output.closure_loss is None:
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\loops\optimization\automatic.py:319, in _AutomaticOptimization._training_step(self, kwargs)
#     317 trainer = self.trainer
# --> 319 training_step_output = call._call_strategy_hook(trainer, "training_step", *kwargs.values())
#     320 self.trainer.strategy.post_training_step()  # unused hook - call anyway for backward compatibility
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\trainer\call.py:328, in _call_strategy_hook(trainer, hook_name, *args, **kwargs)
#     327 with trainer.profiler.profile(f"[Strategy]{trainer.strategy.__class__.__name__}.{hook_name}"):
# --> 328     output = fn(*args, **kwargs)
#     330 # restore current_fx when nested context
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\strategies\strategy.py:391, in Strategy.training_step(self, *args, **kwargs)
#     390     return self._forward_redirection(self.model, self.lightning_module, "training_step", *args, **kwargs)
# --> 391 return self.lightning_module.training_step(*args, **kwargs)
#
# File c:\Users\Fredrik\Documents\GitHub\TomoDpDt\Notebooks\..\tomodpdt\application.py:681, in training_step(self, batch, batch_idx)
#     680         self.translation_params.requires_grad = True
# --> 681
#     682 # Forward pass: estimate projections
#
# File c:\Users\Fredrik\Documents\GitHub\TomoDpDt\Notebooks\..\tomodpdt\application.py:634, in forward(self, idx)
#     633 # If two channels are present, concatenate them - for complex valued projections
# --> 634 elif self.CH > 1 and estimated_projections.dtype == torch.complex64:
#     635
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 4
#       2 start_time = time.time()
#       3 trainer = dl.Trainer(max_epochs=epochs_object_rot, accelerator="auto", log_every_n_steps=None)
# ----> 4 trainer.fit(tomographic_model, DataLoader(idx, batch_size=batch_size_object_rot , shuffle=True))
#       5 print("Training time: ", (time.time() - start_time) / 60, " minutes")
#       7 # Plot the training history
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\trainer\trainer.py:561, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     559 self.training = True
#     560 self.should_stop = False
# --> 561 call._call_and_handle_interrupt(
#     562     self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     563 )
#
# File c:\Users\Fredrik\miniconda3\envs\deeplaydev\Lib\site-packages\lightning\pytorch\trainer\call.py:65, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      63     if isinstance(launcher, _SubprocessScriptLauncher):
#      64         launcher.kill(_get_sigkill_signal())
# ---> 65     exit(1)
#      67 except BaseException as exception:
#      68     _interrupt(trainer, exception)
#
# NameError: name 'exit' is not defined

# %% [markdown]
# ## 5.  Evaluate & Visualize

# %%
# Move it to the GPU if possible for faster plotting
tomographic_model.move_all_to_device(DEV)

# Visualize the final volume and rotations.
plotter = tomodpdt.plotting.TomoPlotter(tomographic_model)

# %%
plotter.plot_sum_object(save_name="Final object")
plotter.plot_sum_object(obj=test_object.cpu(), save_name="Ground truth object")

# %%
plotter.plot_reconstructed_vs_gt(column_headers=["Predicted", "Ground Truth"], forward=True, save_name="Reconstructed vs GT")

# %%
plotter.plot_quaternions(q_gt=q_gt)

# %% [markdown]
# The most effective way to visualize and compare the reconstructed volume to the ground truth is through interactive 3D plots using `plotly`.

# %%
# Uncomment belowto visualize the 3D volume
# tomodpdt.plotting.visualize_3d_volume(tomographic_model.volume.detach().cpu(), save_name="Final object 3D")
# tomodpdt.plotting.visualize_3d_volume(test_object.cpu(), save_name="Ground truth object 3D")

# %% [markdown]
# ## 6. Save Result
#
# Once the process is complete, we can save the reconstructed volume and the quaternion parameters to `numpy` arrays.

# %%
# Define where to save the reconstruction results
# save_folder = "path/to/save/folder"

# --- Save the reconstructed 3D volume ---
# Extract the optimized volume from the model and save as a NumPy array
# volume = tomographic_model.get_volume().detach().cpu().numpy()
# np.save(f"{save_folder}/volume.npy", volume)

# --- Save the optimized quaternions ---
# Extract the final quaternion parameters and save them as a NumPy array
# quaternions_pred = tomographic_model.get_quaternions_final().detach().cpu().numpy()
# np.save(f"{save_folder}/quaternions.npy", quaternions_pred)
